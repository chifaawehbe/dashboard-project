# %%
import pandas as pd
import numpy as np

# %%
import datetime

# %%
df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')

# %%
import sys
sys.getsizeof(covid)
# Out:
# 145489313

# %%
# covid.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    female_smokers  male_smokers  handwashing_facilities  \
# 0             NaN           NaN                  37.746
# 1             NaN           NaN                  37.746
# 2             NaN           NaN                  37.746
# 3             NaN           NaN                  37.746
# 4             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
#
# [5 rows x 67 columns]

# %%
covid = pd.read_csv('owid-covid-data.csv')

# %%
covid
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 177138      ZWE    Africa     Zimbabwe  2022-04-03     246525.0       44.0
# 177139      ZWE    Africa     Zimbabwe  2022-04-04     246612.0       87.0
# 177140      ZWE    Africa     Zimbabwe  2022-04-05     246744.0      132.0
# 177141      ZWE    Africa     Zimbabwe  2022-04-06     246803.0       59.0
# 177142      ZWE    Africa     Zimbabwe  2022-04-07     246870.0       67.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      NaN           NaN         NaN                  NaN
# 1                      NaN           NaN         NaN                  NaN
# 2                      NaN           NaN         NaN                  NaN
# 3                      NaN           NaN         NaN                  NaN
# 4                      NaN           NaN         NaN                  NaN
# ...                    ...           ...         ...                  ...
# 177138             100.714        5446.0         0.0                1.143
# 177139              97.857        5451.0         5.0                1.857
# 177140             100.286        5451.0         0.0                1.714
# 177141              88.714        5453.0         2.0                1.857
# 177142              83.429        5455.0         2.0                1.571
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# 0       ...             NaN           NaN                  37.746
# 1       ...             NaN           NaN                  37.746
# 2       ...             NaN           NaN                  37.746
# 3       ...             NaN           NaN                  37.746
# 4       ...             NaN           NaN                  37.746
# ...     ...             ...           ...                     ...
# 177138  ...             1.6          30.7                  36.791
# 177139  ...             1.6          30.7                  36.791
# 177140  ...             1.6          30.7                  36.791
# 177141  ...             1.6          30.7                  36.791
# 177142  ...             1.6          30.7                  36.791
#
#         hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                              0.5            64.83                    0.511
# 1                              0.5            64.83                    0.511
# 2                              0.5            64.83                    0.511
# 3                              0.5            64.83                    0.511
# 4                              0.5            64.83                    0.511
# ...                            ...              ...                      ...
# 177138                         1.7            61.49                    0.571
# 177139                         1.7            61.49                    0.571
# 177140                         1.7            61.49                    0.571
# 177141                         1.7            61.49                    0.571
# 177142                         1.7            61.49                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        NaN                          NaN
# 1                                        NaN                          NaN
# 2                                        NaN                          NaN
# 3                                        NaN                          NaN
# 4                                        NaN                          NaN
# ...                                      ...                          ...
# 177138                                   NaN                          NaN
# 177139                                   NaN                          NaN
# 177140                                   NaN                          NaN
# 177141                                   NaN                          NaN
# 177142                                   NaN                          NaN
#
#         excess_mortality  excess_mortality_cumulative_per_million
# 0                    NaN                                      NaN
# 1                    NaN                                      NaN
# 2                    NaN                                      NaN
# 3                    NaN                                      NaN
# 4                    NaN                                      NaN
# ...                  ...                                      ...
# 177138               NaN                                      NaN
# 177139               NaN                                      NaN
# 177140               NaN                                      NaN
# 177141               NaN                                      NaN
# 177142               NaN                                      NaN
#
# [177143 rows x 67 columns]

# %%
covid['date']
# Out:
# 0         2020-02-24
# 1         2020-02-25
# 2         2020-02-26
# 3         2020-02-27
# 4         2020-02-28
#              ...
# 177138    2022-04-03
# 177139    2022-04-04
# 177140    2022-04-05
# 177141    2022-04-06
# 177142    2022-04-07
# Name: date, Length: 177143, dtype: object

# %%
today = datetime.date.today()
today
# Out:
# datetime.date(2022, 4, 22)

# %%
tomorrow = today + datetime.timedelta(days=1)

# %%
tomorrow
# Out:
# datetime.date(2022, 4, 23)
